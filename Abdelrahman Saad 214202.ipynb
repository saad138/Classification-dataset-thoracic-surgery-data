# %% [markdown]
# ## Dataset description:
# ## The data is dedicated to classification problem related to the post-operative life expectancy in the lung cancer patients: class 1 - death within one year after surgery, class 2 - survival.

# %%
pip install ucimlrepo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
thoracic_surgery_data = fetch_ucirepo(id=277) 
  
# data (as pandas dataframes) 
X = thoracic_surgery_data.data.features 
y = thoracic_surgery_data.data.targets 
  
# metadata 
print(thoracic_surgery_data.metadata) 
  
# variable information 
print(thoracic_surgery_data.variables)
# Out:
# {'uci_id': 277, 'name': 'Thoracic Surgery Data', 'repository_url': 'https://archive.ics.uci.edu/dataset/277/thoracic+surgery+data', 'data_url': 'https://archive.ics.uci.edu/static/public/277/data.csv', 'abstract': 'The data is dedicated to classification problem related to the post-operative life expectancy in the lung cancer patients: class 1 - death within one year after surgery, class 2 - survival.', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 470, 'num_features': 16, 'feature_types': ['Integer', 'Real'], 'demographics': ['Age'], 'target_col': ['Risk1Yr'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2014, 'last_updated': 'Fri Nov 03 2023', 'dataset_doi': '10.24432/C5Z60N', 'creators': ['Marek Lubicz', 'Konrad Pawelczyk', 'Adam Rzechonek', 'Jerzy Kolodziej'], 'intro_paper': {'title': 'Boosted SVM for extracting rules from imbalanced data in application
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#Fetch the dataset
df = pd.concat([X, y], axis=1)
df.head()
# Out:
#     DGN  PRE4  PRE5  PRE6 PRE7 PRE8 PRE9 PRE10 PRE11 PRE14 PRE17 PRE19 PRE25  \
# 0  DGN2  2.88  2.16  PRZ1    F    F    F     T     T  OC14     F     F     F
# 1  DGN3  3.40  1.88  PRZ0    F    F    F     F     F  OC12     F     F     F
# 2  DGN3  2.76  2.08  PRZ1    F    F    F     T     F  OC11     F     F     F
# 3  DGN3  3.68  3.04  PRZ0    F    F    F     F     F  OC11     F     F     F
# 4  DGN3  2.44  0.96  PRZ2    F    T    F     T     T  OC11     F     F     F
#
#   PRE30 PRE32  AGE Risk1Yr
# 0     T     F   60       F
# 1     T     F   51       F
# 2     T     F   59       F
# 3     F     F   54       F
# 4     T     F   73       T

# %%
df.columns
# Out:
# Index(['DGN', 'PRE4', 'PRE5', 'PRE6', 'PRE7', 'PRE8', 'PRE9', 'PRE10', 'PRE11',
#        'PRE14', 'PRE17', 'PRE19', 'PRE25', 'PRE30', 'PRE32', 'AGE', 'Risk1Yr'],
#       dtype='object')

# %%
df.shape
# Out:
# (470, 17)

# %%
#Check null values
sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')
plt.show()

# %% [markdown]
# ## Handle outliers

# %%
#Check outliers
plt.figure
sns.boxplot(x= "PRE4",data = df, palette='winter')
plt.show()

# %%
#Handle it
df.drop(df[(df['PRE4'] < 2)].index, inplace = True)
df.drop(df[(df['PRE4'] > 5.5)].index, inplace = True)

# %%
#check outliers
plt.figure
sns.boxplot(x= "PRE5",data = df, palette='winter')
plt.show()

# %%
#hanlde it
df.drop(df[(df['PRE4'] > 10)].index, inplace = True)

# %%
plt.figure
sns.boxplot(x= "AGE",data = df, palette='winter')
plt.show()

# %%
df.drop(df[(df['AGE'] < 30)].index, inplace = True)
df.drop(df[(df['AGE'] > 80)].index, inplace = True)

# %%
df.shape
# Out:
# (442, 17)

# %% [markdown]
# ## Convert the attributes to numbers

# %%
df['DGN']=df['DGN'].replace('DGN1',1)
df['DGN']=df['DGN'].replace('DGN2',2)
df['DGN']=df['DGN'].replace('DGN3',3)
df['DGN']=df['DGN'].replace('DGN4',4)
df['DGN']=df['DGN'].replace('DGN5',5)
df['DGN']=df['DGN'].replace('DGN6',6)
df['DGN']=df['DGN'].replace('DGN8',8)
#df['Risk1Yr']=df['Risk1Yr'].replace('F',0)
#df['Risk1Yr']=df['Risk1Yr'].replace('T',1)

# %%
df['PRE6']=df['PRE6'].replace('PRZ0',0)
df['PRE6']=df['PRE6'].replace('PRZ1',1)
df['PRE6']=df['PRE6'].replace('PRZ2',2)

# %%
df['PRE7']=df['PRE7'].replace('F',0)
df['PRE7']=df['PRE7'].replace('T',1)

# %%
df['PRE8']=df['PRE8'].replace('F',0)
df['PRE8']=df['PRE8'].replace('T',1)

# %%
df['PRE9']=df['PRE9'].replace('F',0)
df['PRE9']=df['PRE9'].replace('T',1)

# %%
df['PRE10']=df['PRE10'].replace('F',0)
df['PRE10']=df['PRE10'].replace('T',1)

# %%
df['PRE11']=df['PRE11'].replace('F',0)
df['PRE11']=df['PRE11'].replace('T',1)

# %%
df['PRE14']=df['PRE14'].replace('OC11',11)
df['PRE14']=df['PRE14'].replace('OC12',12)
df['PRE14']=df['PRE14'].replace('OC13',13)
df['PRE14']=df['PRE14'].replace('OC14',14)

# %%
df['PRE17']=df['PRE17'].replace('F',0)
df['PRE17']=df['PRE17'].replace('T',1)
df['PRE19']=df['PRE19'].replace('F',0)
df['PRE19']=df['PRE19'].replace('T',1)
df['PRE25']=df['PRE25'].replace('F',0)
df['PRE25']=df['PRE25'].replace('T',1)
df['PRE30']=df['PRE30'].replace('F',0)
df['PRE30']=df['PRE30'].replace('T',1)
df['PRE32']=df['PRE32'].replace('F',0)
df['PRE32']=df['PRE32'].replace('T',1)

# %%
#WE will use it later
#WE will use it later
#WE will use it later
#WE will use it later
df_imbalance=df

# %%
df['Risk1Yr']=df['Risk1Yr'].replace('F',0)
df['Risk1Yr']=df['Risk1Yr'].replace('T',1)

# %%
# Identify relationships between variables.
plt.figure(figsize = (25,10))
sns.heatmap(df.corr(),annot=True);

# %%
#Feature selection{Drop Columns which have bad impact on target column}
df=df.drop(['AGE','PRE25','DGN','PRE19','PRE30'], axis=1)
df.head()
# Out:
#    PRE4  PRE5  PRE6  PRE7  PRE8  PRE9  PRE10  PRE11  PRE14  PRE17  PRE32  \
# 0  2.88  2.16     1     0     0     0      1      1     14      0      0
# 1  3.40  1.88     0     0     0     0      0      0     12      0      0
# 2  2.76  2.08     1     0     0     0      1      0     11      0      0
# 3  3.68  3.04     0     0     0     0      0      0     11      0      0
# 4  2.44  0.96     2     0     1     0      1      1     11      0      0
#
#    Risk1Yr
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1

# %%
#WE will use it later
#WE will use it later
#WE will use it later
#WE will use it later
dfgroup=df

# %%
# Spliting the dataset to Independent Variables (X) and dependent Variables (Y) which is the predict column
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
#Spliting dataset into training set and test set i choose the test size to be 25% of the data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 1)

# %%
#Put all the values in the datset on the same scale
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # Individual Models

# %%
#Get the best value for n_estimators for RandomForestClassifier and aplly the model on the dataset.
#Get the best value for n_estimators for RandomForestClassifier and aplly the model on the dataset.
#Get the best value for n_estimators for RandomForestClassifier and aplly the model on the dataset.
#Get the best value for n_estimators for RandomForestClassifier and aplly the model on the dataset.
from sklearn.ensemble import RandomForestClassifier
n_range = range(1, 200,10)
tr_scores = []
te_scores = []
for n in n_range:
    RFC = RandomForestClassifier(n_estimators=n, max_leaf_nodes=7, n_jobs=-1, random_state=42)
    RFC.fit(X_train, y_train)
    tr_scores.append(RFC.score(X_train,y_train))
    te_scores.append(RFC.score(X_test,y_test))

plt.plot(n_range, tr_scores)
plt.plot(n_range, te_scores)
plt.xlabel('Number of estimators')
plt.ylabel('Accuracy')
plt.show()
print("Accuracy for RandomForest on training set: {:.3f}".format(RFC.score(X_train, y_train)))
print("Accuracy for RandomForest on testing set: {:.3f}\n".format(RFC.score(X_test, y_test)))
# Out:
# Accuracy for RandomForest on training set: 0.846
# Accuracy for RandomForest on testing set: 0.856

# %%
#Apply SVC model on the dataset
from sklearn.svm import SVC
SVM = SVC(kernel='linear', C=1.0, probability=True, random_state=42)
SVM.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', probability=True, random_state=42)

# %%
print("Accuracy for SVM on training set: {:.3f}".format(SVM.score(X_train, y_train)))
print("Accuracy for SVM on testing set: {:.3f}\n".format(SVM.score(X_test, y_test)))
# Out:
# Accuracy for SVM on training set: 0.846
# Accuracy for SVM on testing set: 0.856

# %%
#Apply LR model on the dataset
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression(random_state = 42)
LR.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
print("Accuracy for LogisticRegression on training set: {:.3f}".format(LR.score(X_train, y_train)))
print("Accuracy for LogisticRegression on testing set: {:.3f}\n".format(LR.score(X_test, y_test)))
# Out:
# Accuracy for LogisticRegression on training set: 0.843
# Accuracy for LogisticRegression on testing set: 0.856

# %%
#Aplly DT model on the dataset
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier(random_state=42, max_depth=2)
DT.fit(X_train, y_train)

print("Accuracy for DecisionTree on training set: {:.3f}".format(DT.score(X_train, y_train)))
print("Accuracy for DecisionTree on testing set: {:.3f}\n".format(DT.score(X_test, y_test)))
# Out:
# Accuracy for DecisionTree on training set: 0.846
# Accuracy for DecisionTree on testing set: 0.856

# %% [markdown]
# # Ensemble Models

# %% [markdown]
# ## I set the prbabiltiy of SVM true, so i can apply voting calssifier on it

# %%
from sklearn.ensemble import VotingClassifier
# Ensemble Model (Voting Classifier)
ensemble_model = VotingClassifier(estimators=[
    ('svc', SVM),
    ('random_forest', RFC),
    ('logistic_regression', LR),
    ('decision tree', DT)
], voting='soft')  
#Uses voting soft to draw the ROC curve
#Uses voting soft to draw the ROC curve
#Uses voting soft to draw the ROC curve
#Uses voting soft to draw the ROC curve
# Train the ensemble model
ensemble_model.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('svc',
#                               SVC(kernel='linear', probability=True,
#                                   random_state=42)),
#                              ('random_forest',
#                               RandomForestClassifier(max_leaf_nodes=7,
#                                                      n_estimators=191,
#                                                      n_jobs=-1,
#                                                      random_state=42)),
#                              ('logistic_regression',
#                               LogisticRegression(random_state=42)),
#                              ('decision tree',
#                               DecisionTreeClassifier(max_depth=2,
#                                                      random_state=42))],
#                  voting='soft')

# %%
print("Accuracy for Voting on training set: {:.3f}".format(ensemble_model.score(X_train, y_train)))
print("Accuracy for Voting on testing set: {:.3f}".format(ensemble_model.score(X_test, y_test)))
# Out:
# Accuracy for Voting on training set: 0.846
# Accuracy for Voting on testing set: 0.856

# %%
# Apply BaggingCalssifer for DT on the dataset and print the accuracy
from sklearn.ensemble import BaggingClassifier
bagging = BaggingClassifier(
    base_estimator = DT, n_estimators=500,
    max_samples=100, bootstrap=True, n_jobs=-1, random_state=42)

bagging.fit(X_train, y_train)
print("Accuracy for Bagging ENSAMBLE on training set: {:.3f}".format(bagging.score(X_train, y_train)))
print("Accuracy for Bagging ENSAMBLE on testing set: {:.3f}".format(bagging.score(X_test, y_test)))
# Out:
# Accuracy for Bagging ENSAMBLE on training set: 0.843
# Accuracy for Bagging ENSAMBLE on testing set: 0.865

# %%
# Apply AdaBoostClassifier for RF on the dataset and print the accuracy
from sklearn.ensemble import AdaBoostClassifier
ada_rfc = AdaBoostClassifier(
    (RFC))
ada_rfc.fit(X_train, y_train)
print("Accuracy for Adaboost ENSAMBLE on training set: {:.3f}".format(ada_rfc.score(X_train, y_train)))
print("Accuracy for Adaboost ENSAMBLE on testing set: {:.3f}".format(ada_rfc.score(X_test, y_test)))
# Out:
# Accuracy for Adaboost ENSAMBLE on training set: 0.997
# Accuracy for Adaboost ENSAMBLE on testing set: 0.811

# %% [markdown]
# Overfitted

# %% [markdown]
# # Comparsion

# %%
from sklearn.metrics import roc_curve, auc

# List of classifier(Individual and ensemble) models to evaluate
clfs = [ LogisticRegression(), DecisionTreeClassifier(), RandomForestClassifier(), AdaBoostClassifier(RFC), BaggingClassifier(
    base_estimator = DT, n_estimators=500,
    max_samples=100, bootstrap=True, n_jobs=-1, random_state=42), VotingClassifier(estimators=[('random_forest',
                              RandomForestClassifier(max_leaf_nodes=7,
                                                     n_estimators=191,
                                                     n_jobs=-1,
                                                     random_state=42)),
                             ('logistic_regression',
                              LogisticRegression(random_state=42)),
                             ('decision tree',
                              DecisionTreeClassifier(max_depth=2,
                                                     random_state=42))],
                 voting='soft')]

# Dictionary to store ROC curves
roc_curves = {}

# Evaluate each classifier
for clf in clfs:
    name = clf.__class__.__name__
    clf.fit(X_train, y_train)
    y_probs = clf.predict_proba(X_test)[:, 1]
    fpr, tpr, _ = roc_curve(y_test, y_probs)
    roc_auc = auc(fpr, tpr)
    roc_curves[name] = (fpr, tpr, roc_auc)

# Plot ROC curves
plt.figure(figsize=(8, 6))
for name, (fpr, tpr, auc_score) in roc_curves.items():
    plt.plot(fpr, tpr, label=f'{name} (AUC = {auc_score:0.2f})')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.grid()
plt.title('ROC Curve Comparison')
plt.savefig('roc_comparison.png')

# %% [markdown]
# ALL the models achieved poor performance except BaggingBoostClassifier achived acceptable AUC score

# %%
from sklearn.metrics import roc_curve, roc_auc_score

def best_threshold(y_test, y_pred):
# get the fpr, tpr, and thresholds arrays from the roc_curve http://localhost:8888/notebooks/Abalone/Abalone.ipynb#2--Best-threshold,-TPR,-FPR,----AUC,-F1-and----ACCfunction
    fpr, tpr, thresholds = roc_curve(y_test, y_pred)
#Evalute auc from roc_auc_score    
    auc = roc_auc_score(y_test, y_pred)
   
    best_thresh = None
    best_tpr = None
    best_fpr = None
    
# compute the Euclidean distance from the top-left corner for each point on the ROC curve
    D = np.sqrt((1 - tpr) ** 2 + fpr ** 2)
    ix = np.argmin(D)
# find the optimal threshold, tpr, and fpr values 
    best_thresh = thresholds[ix]
    best_tpr = tpr[ix]
    best_fpr = fpr[ix]

    print('The Euclidean distance method minimizes the distance from the top-left corner of the ROC plot, which corresponds to the ideal point of TPR = 1 and FPR = 0.')


   
    return best_thresh, best_tpr, best_fpr

# %%
from sklearn.metrics import f1_score,accuracy_score

def compare_thresholds(clfs): 
    df = pd.DataFrame(columns=['Classifier', 'Threshold', 'TPR', 'FPR', 'AUC', 'F1'])
# fit the classifier on the train set
    for clf in clfs:
        clf.fit(X_train, y_train) 
# get the probability estimates for the test set        
        probas_ = clf.predict_proba(X_test)
    
#get the outputs from  best_threshold function      
        best_thresh, best_tpr, best_fpr = best_threshold(y_test, probas_[:, 1])
# Evalute the f1 score from the f1_score function using 0.5 as the default threshold  
        f1 = f1_score(y_test, probas_[:, 1] > best_thresh)
# Evalute the auc score from the roc_auc_score function
        auc = roc_auc_score(y_test, probas_[:, 1]> best_thresh)
# Evalute accuracy from accuracy_score function     
        acc = accuracy_score(y_test,probas_[:,1]>best_thresh)
         
        df = df.append({'Classifier': clf.__class__.__name__, 'Threshold': best_thresh, 'TPR': best_tpr, 'FPR': best_fpr, 'AUC': auc, 'F1': f1,'ACC': acc}, ignore_index=True)
     
    return df

# %%
# Compare between the 6 models
classifiers = [LogisticRegression(), DecisionTreeClassifier(), SVC(kernel='linear', probability=True, random_state=42), RandomForestClassifier(),AdaBoostClassifier(RFC), BaggingClassifier(
    base_estimator = DT, n_estimators=500,
    max_samples=100, bootstrap=True, n_jobs=-1, random_state=42),VotingClassifier(estimators=[('svc',
                              SVC(kernel='linear', probability=True,
                                  random_state=42)),
                             ('random_forest',
                              RandomForestClassifier(max_leaf_nodes=7,
                                                     n_estimators=191,
                                                     n_jobs=-1,
                                                     random_state=42)),
                             ('logistic_regression',
                              LogisticRegression(random_state=42)),
                             ('decision tree',
                              DecisionTreeClassifier(max_depth=2,
                                                     random_state=42))],
                 voting='soft')]
compare_thresholds(classifiers)
# Out:
# The Euclidean distance method minimizes the distance from the top-left corner of the ROC plot, which corresponds to the ideal point of TPR = 1 and FPR = 0.
# The Euclidean distance method minimizes the distance from the top-left corner of the ROC plot, which corresponds to the ideal point of TPR = 1 and FPR = 0.
# The Euclidean distance method minimizes the distance from the top-left corner of the ROC plot, which corresponds to the ideal point of TPR = 1 and FPR = 0.
# The Euclidean distance method minimizes the distance from the top-left corner of the ROC plot, which corresponds to the ideal point of TPR = 1 and FPR = 0.
# C:\Users\saad3\AppData\Local\Temp\ipykernel_39268\2253664603.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# ## Clustring

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 5, n_init = 10, max_iter = 300)
y_kmeans = kmeans.fit_predict(dfgroup)

# %% [markdown]
# ## Calculate bais and variance

# %%
# !pip install mlxtend

# %%
# Calculate it for ADAboostCalssifier
# Calculate it for ADAboostCalssifier
from mlxtend.evaluate import bias_variance_decomp
mse, bias, var = bias_variance_decomp\
(ada_rfc, X_train, y_train, X_test, y_test, loss='mse', num_rounds=20, random_seed=42)

# %%
#Print bias and varianvce
print('Bias: %.3f' % bias)
print('Variance: %.3f' % var)
# Out:
# Bias: 0.142
# Variance: 0.035

# %% [markdown]
# A variance of 0.035 is relatively low, indicating that the model is not overly sensitive to noise in the training data.
#
# A bias of 0.142 suggests that, on average, the model's predictions are off by this amount. It indicates a systematic error in the predictions.

# %%
#Draw learning cursve to notice bias and variance ADA_rfc
from sklearn.model_selection import learning_curve

train_sizes_model, train_scores_model, valid_scores_model, *_ =learning_curve(ada_rfc, X, y,cv=5,
                    scoring='accuracy',n_jobs=-1)
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.scatter(x=train_sizes_model,y= train_scores_model.mean(axis=1), color='b')
ax.scatter(x=train_sizes_model,y=valid_scores_model.mean(axis=1), color='r')
ax.plot(train_sizes_model,train_scores_model.mean(axis=1), color='b')
ax.plot(train_sizes_model,valid_scores_model.mean(axis=1), color='r')
ax.set_xlabel('Data Range')
ax.set_ylabel('Accuracy')
ax.set_title('Learning Curve')
plt.show()

# %%
# Calculate it for RandomForestClassifier
# Calculate it for RandomForestClassifier
from mlxtend.evaluate import bias_variance_decomp
mse, bias, var = bias_variance_decomp\
(RFC, X_train, y_train, X_test, y_test, loss='mse', num_rounds=20, random_seed=42)

# %%
#Print bias and varianvce
print('Bias: %.3f' % bias)
print('Variance: %.3f' % var)
# Out:
# Bias: 0.144
# Variance: 0.000

# %% [markdown]
# A bias of 0.144 suggests that, on average, the model's predictions are off by this amount. It indicates a systematic error in the predictions.
#
#
# A variance of 0.000 indicates very low sensitivity to variations in the training data.

# %%
#Draw learning cursve to notice bias and variance for RFC
train_sizes_model, train_scores_model, valid_scores_model, *_ =learning_curve(RFC, X, y,cv=5,
                    scoring='accuracy',n_jobs=-1)
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.scatter(x=train_sizes_model,y= train_scores_model.mean(axis=1), color='b')
ax.scatter(x=train_sizes_model,y=valid_scores_model.mean(axis=1), color='r')
ax.plot(train_sizes_model,train_scores_model.mean(axis=1), color='b')
ax.plot(train_sizes_model,valid_scores_model.mean(axis=1), color='r')
ax.set_xlabel('Data Range')
ax.set_ylabel('Accuracy')
ax.set_title('Learning Curve')
plt.show()

# %% [markdown]
# # Handle imbalance dataset

# %%
# Checking missing values
df_imbalance.isnull().sum()
# Out:
# DGN        0
# PRE4       0
# PRE5       0
# PRE6       0
# PRE7       0
# PRE8       0
# PRE9       0
# PRE10      0
# PRE11      0
# PRE14      0
# PRE17      0
# PRE19      0
# PRE25      0
# PRE30      0
# PRE32      0
# AGE        0
# Risk1Yr    0
# dtype: int64

# %%
#Counts number of Death
sns.countplot(data = df_imbalance , x= 'Risk1Yr');

# %% [markdown]
# ## The dataset is imbalanced

# %%
boxplot =df_imbalance.boxplot( figsize=(10,8))

# %%
#Splitting the dataset to x and y
x_Dataset=df_imbalance.iloc[:,:-1]
y_Dataset=df_imbalance.iloc[:,-1]

# %% [markdown]
# ## Detect outliers

# %%
#Define the outlier
from sklearn.covariance import EllipticEnvelope
outlierDetector1 =  EllipticEnvelope(contamination=0.2)
result=outlierDetector1.fit_predict(x_Dataset)

# %%
Outliers=x_Dataset[result==-1]
print("Number of detected outliers is " +str(len(Outliers)))
# Out:
# Number of detected outliers is 89

# %%
ax=y_Dataset[result!=-1].value_counts().plot(kind='bar',color=['red','blue'],
                                          title='Risk Category After Elliptic envelope',figsize=(8, 6))

plt.xticks(range(2),['F','T'])
ax.set_xlabel("Category",fontsize=16)
ax.set_ylabel("Number of risks",fontsize=14)
plt.show()

# %%
#Define the outlier
from sklearn.neighbors import LocalOutlierFactor
outlierDetector2 =  LocalOutlierFactor(n_neighbors=20)
result2=outlierDetector2.fit_predict(x_Dataset)

# %%
Outliers=x_Dataset[result2==-1]
print("Number of detected outliers is " +str(len(Outliers)))
# Out:
# Number of detected outliers is 22

# %%
ax=y_Dataset[result2!=-1].value_counts().plot(kind='bar',color=['red','blue'],
                                          title='Risk Category After Elliptic envelope',figsize=(8, 6))

plt.xticks(range(2),['F','T'])
ax.set_xlabel("Category",fontsize=16)
ax.set_ylabel("Number of risks",fontsize=14)
plt.show()

# %%
#Define the outlier
from sklearn.ensemble import IsolationForest
outlierDetector =  IsolationForest(n_estimators=100,random_state = 42)
result=outlierDetector.fit_predict(x_Dataset)

# %%
Outliers=x_Dataset[result==-1]
print("Number of detected outliers is " +str(len(Outliers)))
# Out:
# Number of detected outliers is 65

# %%
ax=y_Dataset[result2!=-1].value_counts().plot(kind='bar',color=['red','blue'],
                                          title='Risks Category After Elliptic envelope',figsize=(8, 6))

plt.xticks(range(2),['F','T'])
ax.set_xlabel("Category",fontsize=16)
ax.set_ylabel("Number of risks",fontsize=14)
plt.show()

# %% [markdown]
# ## Handle imbalanced dataset using three methods

# %%
#Split the dataset
x_train, x_test, y_train, y_test = train_test_split(x_Dataset, y_Dataset, test_size=0.25,random_state=42)

# %%
## Install imblearn to use oversampling techniques
# !pip install -U imbalanced-learn

# %%
from imblearn.over_sampling import SMOTE,RandomOverSampler
y_Dataset.value_counts()
# Out:
# 0    375
# 1     67
# Name: Risk1Yr, dtype: int64

# %% [markdown]
# ## RandomOverSampler

# %%
#newData=DatasetWithMiss.copy()
overSampler = RandomOverSampler(random_state=42)
overX1,overY1=overSampler.fit_resample(x_Dataset, y_Dataset)

# %%
pd.DataFrame(overY1,columns=['Risk1Yr'])['Risk1Yr'].value_counts()
# Out:
# 0    375
# 1    375
# Name: Risk1Yr, dtype: int64

# %%
# First over sampling to make all classes equal
# As observed after undersampling , the two classes are balanced
ax=pd.DataFrame(overY1,columns=['Risk1Yr'])['Risk1Yr'].value_counts().plot(kind='bar',color=['red','blue'],
                                          title='Risk Category',figsize=(8, 6))

plt.xticks(range(2),['F','T'])
ax.set_xlabel("Category",fontsize=16)
ax.set_ylabel("Number of Risk",fontsize=14)
plt.show()

# %%
scaler = StandardScaler()
x_traini, x_testi, y_traini, y_testi = train_test_split(overX1, overY1, test_size=0.25,random_state=42)
x_traini=scaler.fit_transform(x_traini)
x_testi=scaler.fit_transform(x_testi)
rf= RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(x_traini, y_traini)
# Out:
# RandomForestClassifier(random_state=42)

# %%
print("Accuracy for RandomOverSampler on training set: {:.3f}".format(rf.score(x_traini, y_traini)))
print("Accuracy for RandomOverSampler on testing set: {:.3f}\n".format(rf.score(x_testi, y_testi)))
# Out:
# Accuracy for RandomOverSampler on training set: 1.000
# Accuracy for RandomOverSampler on testing set: 0.803

# %% [markdown]
# Overfitted

# %% [markdown]
# ## SMOTE METHOD

# %%
oversample = SMOTE(random_state=42)
overX,overY=oversample.fit_resample(x_Dataset, y_Dataset)

# %%
ax=pd.DataFrame(overY,columns=['Risk1Yr'])['Risk1Yr'].value_counts().plot(kind='bar',color=['red','blue'],
                                          title='Risk Category',figsize=(8, 6))

plt.xticks(range(2),['F','T'])
ax.set_xlabel("Category",fontsize=16)
ax.set_ylabel("Number of Risk",fontsize=14)
plt.show()

# %%
x_trainii, x_testii, y_trainii, y_testii = train_test_split(overX, overY, test_size=0.25,random_state=42)
x_trainii=scaler.fit_transform(x_trainii)
x_testii=scaler.fit_transform(x_testi)
rf2= RandomForestClassifier(n_estimators=100, random_state=42)
rf2.fit(x_trainii, y_trainii)
# Out:
# RandomForestClassifier(random_state=42)

# %%
print("Accuracy for SMOTE on training set: {:.3f}".format(rf2.score(x_trainii, y_trainii)))
print("Accuracy for SMOTE on testing set: {:.3f}\n".format(rf2.score(x_testii, y_testii)))
# Out:
# Accuracy for SMOTE on training set: 1.000
# Accuracy for SMOTE on testing set: 0.681

# %% [markdown]
# Overfitted

# %% [markdown]
# ## MIXED METHOD

# %%
from imblearn.combine import SMOTETomek

# %%
x_trainiii,x_testiii,y_trainiii,y_testiii = train_test_split(x_Dataset, y_Dataset, test_size=0.25, random_state=0)

smt = SMOTETomek(random_state=42,smote=SMOTE(k_neighbors=2))
X_res, y_res = smt.fit_resample(x_trainiii, y_trainiii)

# %%
X_res=scaler.fit_transform(X_res)
x_testiii=scaler.fit_transform(x_testiii)
rf3= RandomForestClassifier(n_estimators=100, random_state=42)
rf3.fit(X_res, y_res)
# Out:
# RandomForestClassifier(random_state=42)

# %%
print("Accuracy for MIXED on training set: {:.3f}".format(rf3.score(X_res, y_res)))
print("Accuracy for MIXED on testing set: {:.3f}\n".format(rf3.score(x_testiii, y_testiii)))
# Out:
# Accuracy for MIXED on training set: 1.000
# Accuracy for MIXED on testing set: 0.739

# %% [markdown]
# Overfitted

# %% [markdown]
# # Compare handle imbalance methods performance

# %% [markdown]
# ## ROC CURVE

# %% [markdown]
# ## RandomOverSampler method

# %%
# RandomOverSampler method use RandomforstClassifier
# RandomOverSampler method use RandomforstClassifier
# RandomOverSampler method use RandomforstClassifier
from sklearn.metrics import roc_curve, auc

# List of classifier models to evaluate
clfs = [RandomForestClassifier(random_state=42)]
# Dictionary to store ROC curves
roc_curves = {}

# Evaluate each classifier
for clf in clfs:
    name = clf.__class__.__name__
    clf.fit(x_traini, y_traini)
    y_probs = clf.predict_proba(x_testi)[:, 1]
    fpr, tpr, _ = roc_curve(y_testi, y_probs)
    roc_auc = auc(fpr, tpr)
    roc_curves[name] = (fpr, tpr, roc_auc)

# Plot ROC curves
plt.figure(figsize=(8, 6))
for name, (fpr, tpr, auc_score) in roc_curves.items():
    plt.plot(fpr, tpr, label=f'{name} (AUC = {auc_score:0.2f})')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.grid()
plt.title('ROC Curve for RandomOverSampler')
plt.savefig('roc_comparison.png')

# %% [markdown]
# ## The RandomOverSampler method with RandomForestClassifier model indicating high sensitivity and low false positive rate

# %% [markdown]
# ## SMOTE METHOD

# %%
#SMOTE METHOD
#SMOTE METHOD
#SMOTE METHOD

from sklearn.metrics import roc_curve, auc

# List of classifier models to evaluate
clfs = [RandomForestClassifier(random_state=42)]
# Dictionary to store ROC curves
roc_curves = {}

# Evaluate each classifier
for clf in clfs:
    name = clf.__class__.__name__
    clf.fit(x_trainii, y_trainii)
    y_probs = clf.predict_proba(x_testii)[:, 1]
    fpr, tpr, _ = roc_curve(y_testii, y_probs)
    roc_auc = auc(fpr, tpr)
    roc_curves[name] = (fpr, tpr, roc_auc)

# Plot ROC curves
plt.figure(figsize=(8, 6))
for name, (fpr, tpr, auc_score) in roc_curves.items():
    plt.plot(fpr, tpr, label=f'{name} (AUC = {auc_score:0.2f})')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.grid()
plt.title('ROC Curve for SMOTE')
plt.savefig('roc_comparison.png')

# %% [markdown]
# ## SMOTE method achieved poor AUC performance

# %% [markdown]
# ## MIXED METHOD

# %%
# MIXED METHOD
# MIXED METHOD
# MIXED METHOD

from sklearn.metrics import roc_curve, auc

# List of classifier models to evaluate
clfs = [RandomForestClassifier(random_state=42)]
# Dictionary to store ROC curves
roc_curves = {}

# Evaluate each classifier
for clf in clfs:
    name = clf.__class__.__name__
    clf.fit(x_trainiii, y_trainiii)
    y_probs = clf.predict_proba(x_testiii)[:, 1]
    fpr, tpr, _ = roc_curve(y_testiii, y_probs)
    roc_auc = auc(fpr, tpr)
    roc_curves[name] = (fpr, tpr, roc_auc)

# Plot ROC curves
plt.figure(figsize=(8, 6))
for name, (fpr, tpr, auc_score) in roc_curves.items():
    plt.plot(fpr, tpr, label=f'{name} (AUC = {auc_score:0.2f})')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.grid()
plt.title('ROC Curve for MIXED')
plt.savefig('roc_comparison.png')
# Out:
# C:\DRIVERS\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## MIXED method achieved very poor AUC score which indicate a bad perfomance

# %% [markdown]
# ## Confusion Matrix

# %%
#FOR RandomOverSampling
#FOR RandomOverSampling
#FOR RandomOverSampling
#FOR RandomOverSampling
import numpy as np
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt
print("Confusion matrix for RandomOverSampling")
# Your existing code
predictions = rf.predict(x_testi)
cm = confusion_matrix(y_testi, predictions, labels=rf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=rf.classes_)

# Create a new figure with a wider x-axis
fig, ax = plt.subplots(figsize=(30, 8))  # Adjust the width (12) as needed
ax.grid(False)
# Plot the confusion matrix on the given axes object
disp.plot(ax=ax)

# Add any other customizations or labels you'd like
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")

# Show the plot
plt.show()
# Out:
# Confusion matrix for RandomOverSampling

# %%
#For SMOTE
#For SMOTE
#For SMOTE
#For SMOTE
import numpy as np
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt
print("Confusion matrix for SMOTE")

# Your existing code
predictions = rf2.predict(x_testii)
cm = confusion_matrix(y_testii, predictions, labels=rf2.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=rf2.classes_)

# Create a new figure with a wider x-axis
fig, ax = plt.subplots(figsize=(30, 8))  # Adjust the width (12) as needed
ax.grid(False)
# Plot the confusion matrix on the given axes object
disp.plot(ax=ax)

# Add any other customizations or labels you'd like
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")

# Show the plot
plt.show()
# Out:
# Confusion matrix for SMOTE

# %%
#MIXED
#MIXED
#MIXED
import numpy as np
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt
print("Confusion matrix for MIXED")

# Your existing code
predictions = rf3.predict(x_testiii)
cm = confusion_matrix(y_testiii, predictions, labels=rf3.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=rf3.classes_)

# Create a new figure with a wider x-axis
fig, ax = plt.subplots(figsize=(30, 8))  # Adjust the width (12) as needed
ax.grid(False)
# Plot the confusion matrix on the given axes object
disp.plot(ax=ax)

# Add any other customizations or labels you'd like
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")

# Show the plot
plt.show()
# Out:
# Confusion matrix for MIXED
